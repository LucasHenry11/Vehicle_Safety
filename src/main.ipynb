# %%
import pandas as pd

# %%
df = pd.read_csv("../data/nhtsa_vehicle_safety_recall_intelligence_ultimate.csv")
df.describe()
# Out:
#        nhtsa_record_id  vehicle_year  vehicle_year_num  \
# count     47707.000000  46705.000000      46705.000000
# mean     167285.682143   2014.684316       2014.684316
# std       70721.828215      6.411211          6.411211
# min       81715.000000   1988.000000       1988.000000
# 25%      112204.500000   2010.000000       2010.000000
# 50%      140588.000000   2015.000000       2015.000000
# 75%      217614.500000   2020.000000       2020.000000
# max      321004.000000   2027.000000       2027.000000
#
#        recall_initiation_date  owner_notification_date  \
# count            4.770700e+04             4.649500e+04
# mean             2.018520e+07             2.018392e+07
# std              4.511637e+04             1.524392e+05
# min              2.010010e+07             1.111111e+07
# 25%              2.015060e+07             2.015080e+07
# 50%              2.019023e+07             2.019032e+07
# 75%              2.022080e+07             2.022082e+07
# ...
